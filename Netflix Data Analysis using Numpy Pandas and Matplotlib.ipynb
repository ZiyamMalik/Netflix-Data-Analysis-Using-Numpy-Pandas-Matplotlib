# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\ziyam\Downloads\netflix_titles.csv")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df["director"].value_counts()
# Out:
# unknown                   2624
# rajiv chilaka               19
# raúl campos, jan suter      18
# marcus raboy                16
# suhas kadav                 16
#                           ...
# eric bross                   1
# will eisenberg               1
# marina seresesky             1
# kenny leon                   1
# mozez singh                  1
# Name: director, Length: 4527, dtype: int64

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df["director"].fillna("unknown",inplace=True)
df["cast"].fillna("unknown",inplace=True)
df["country"].fillna("unknown",inplace=True)
df["rating"].fillna("unknown",inplace=True)
df["duration"].fillna("unknown",inplace=True)
df.dropna(inplace=True)

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8797, dtype: bool

# %%
df["date_added"]=pd.to_datetime(df["date_added"])

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.drop(columns=["released_year"],inplace=True)

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
text_columns=["type","title","director","cast","country","rating","listed_in"]
for col in text_columns:
    df[col]=df[col].str.strip().str.lower()

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    movie   dick johnson is dead  kirsten johnson
# 1         s2  tv show          blood & water          unknown
# 2         s3  tv show              ganglands  julien leclercq
# 3         s4  tv show  jailbirds new orleans          unknown
# 4         s5  tv show           kota factory          unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    movie                 zodiac    david fincher
# 8803   s8804  tv show            zombie dumb          unknown
# 8804   s8805    movie             zombieland  ruben fleischer
# 8805   s8806    movie                   zoom     peter hewitt
# 8806   s8807    movie                 zubaan      mozez singh
#
#                                                    cast        country  \
# 0                                               unknown  united states
# 1     ama qamata, khosi ngema, gail mabalane, thaban...   south africa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8797 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8797 non-null   object
#  1   type          8797 non-null   object
#  2   title         8797 non-null   object
#  3   director      8797 non-null   object
#  4   cast          8797 non-null   object
#  5   country       8797 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8797 non-null   int64
#  8   rating        8797 non-null   object
#  9   duration      8797 non-null   object
#  10  listed_in     8797 non-null   object
#  11  description   8797 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 893.4+ KB

# %%
df.shape
# Out:
# (8797, 12)

# %%
df.describe()
# Out:
#        release_year
# count   8797.000000
# mean    2014.183472
# std        8.822191
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df["type"].value_counts()
# Out:
# movie      6131
# tv show    2666
# Name: type, dtype: int64

# %%
df["country"].unique()
df["country"].nunique()
# Out:
# 749

# %%
df["director"].unique()
df["director"].nunique()
# Out:
# 4527

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    movie              dick johnson is dead
# 1      s2  tv show                     blood & water
# 2      s3  tv show                         ganglands
# 3      s4  tv show             jailbirds new orleans
# 4      s5  tv show                      kota factory
# 5      s6  tv show                     midnight mass
# 6      s7    movie  my little pony: a new generation
# 7      s8    movie                           sankofa
# 8      s9  tv show     the great british baking show
# 9     s10    movie                      the starling
#
#                         director  \
# 0                kirsten johnson
# 1                        unknown
# 2                julien leclercq
# 3                        unknown
# 4                        unknown
# 5                  mike flanagan
# 6  robert cullen, josé luis ucha
# 7                   haile gerima
# 8                andy devonshire
# 9                 theodore melfi
#
# ...

# %%
countries=df["country"].str.split(",").explode().str.strip()
top_10=countries.value_counts().head(10)

# %%
top_10
# Out:
# united states     3684
# india             1046
# unknown            830
# united kingdom     805
# canada             445
# france             393
# japan              317
# spain              232
# south korea        231
# germany            226
# Name: country, dtype: int64

# %%
df["type"].value_counts()
# Out:
# movie      6131
# tv show    2666
# Name: type, dtype: int64

# %%
df.groupby("type").count()
# Out:
#          show_id  title  director  cast  country  date_added  release_year  \
# type
# movie       6131   6131      6131  6131     6131        6131          6131
# tv show     2666   2666      2666  2666     2666        2666          2666
#
#          rating  duration  listed_in  description
# type
# movie      6131      6131       6131         6131
# tv show    2666      2666       2666         2666

# %%
df.value_counts("release_year")
# Out:
# release_year
# 2018    1146
# 2017    1032
# 2019    1030
# 2020     953
# 2016     901
#         ...
# 1959       1
# 1961       1
# 1947       1
# 1966       1
# 1925       1
# Length: 74, dtype: int64

# %%
genres=df["listed_in"].str.split(",").explode().str.strip()
most_common=genres.value_counts()

# %%
most_common
# Out:
# international movies            2752
# dramas                          2427
# comedies                        1674
# international tv shows          1350
# documentaries                    869
# action & adventure               859
# tv dramas                        762
# independent movies               756
# children & family movies         641
# romantic movies                  616
# thrillers                        577
# tv comedies                      574
# crime tv shows                   469
# kids' tv                         449
# docuseries                       394
# music & musicals                 375
# romantic tv shows                370
# horror movies                    357
# stand-up comedy                  343
# reality tv                       255
# british tv shows                 252
# sci-fi & fantasy                 243
# sports movies                    219
# anime series                     175
# spanish-language tv shows        173
# ...

# %%
movies=df[df["type"]=="movie"]

# %%
movies
# Out:
#      show_id   type                             title  \
# 0         s1  movie              dick johnson is dead
# 6         s7  movie  my little pony: a new generation
# 7         s8  movie                           sankofa
# 9        s10  movie                      the starling
# 12       s13  movie                      je suis karl
# ...      ...    ...                               ...
# 8801   s8802  movie                           zinzana
# 8802   s8803  movie                            zodiac
# 8804   s8805  movie                        zombieland
# 8805   s8806  movie                              zoom
# 8806   s8807  movie                            zubaan
#
#                            director  \
# 0                   kirsten johnson
# 6     robert cullen, josé luis ucha
# 7                      haile gerima
# 9                    theodore melfi
# 12              christian schwochow
# ...                             ...
# 8801                majid al ansari
# ...

# %%
moviesss=pd.to_numeric(movies["duration"].str.replace("min",''),errors="coerce")

# %%
moviesss.describe()
# Out:
# count    6128.000000
# mean       99.577187
# std        28.290593
# min         3.000000
# 25%        87.000000
# 50%        98.000000
# 75%       114.000000
# max       312.000000
# Name: duration, dtype: float64

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    movie              dick johnson is dead
# 1      s2  tv show                     blood & water
# 2      s3  tv show                         ganglands
# 3      s4  tv show             jailbirds new orleans
# 4      s5  tv show                      kota factory
# 5      s6  tv show                     midnight mass
# 6      s7    movie  my little pony: a new generation
# 7      s8    movie                           sankofa
# 8      s9  tv show     the great british baking show
# 9     s10    movie                      the starling
#
#                         director  \
# 0                kirsten johnson
# 1                        unknown
# 2                julien leclercq
# 3                        unknown
# 4                        unknown
# 5                  mike flanagan
# 6  robert cullen, josé luis ucha
# 7                   haile gerima
# 8                andy devonshire
# 9                 theodore melfi
#
# ...

# %%
type_counts=df["type"].value_counts()

# %%
type_counts.plot(kind="bar")
plt.xlabel("type")
plt.ylabel("values")
plt.title("Movies VS TV Shows")
# Out:
# Text(0.5, 1.0, 'Movies VS TV Shows')

# %%
df.groupby("type")["release_year"].count()
# Out:
# type
# movie      6131
# tv show    2666
# Name: release_year, dtype: int64

# %%
a=df["release_year"].value_counts()

# %%
a
# Out:
# 2018    1146
# 2017    1032
# 2019    1030
# 2020     953
# 2016     901
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: release_year, Length: 74, dtype: int64

# %%
a.plot(kind="line")
plt.xlabel("years")
plt.ylabel("content")
plt.title("content added per year")
# Out:
# Text(0.5, 1.0, 'content added per year')

# %%
countries=df["country"].str.split(",").explode().str.strip()
top_10=countries.value_counts().head(10)

# %%
top_10
# Out:
# united states     3684
# india             1046
# unknown            830
# united kingdom     805
# canada             445
# france             393
# japan              317
# spain              232
# south korea        231
# germany            226
# Name: country, dtype: int64

# %%
top_10.plot(kind="barh")
plt.xlabel("values")
plt.ylabel("countries")
plt.title("top 10 countries")
# Out:
# Text(0.5, 1.0, 'top 10 countries')

# %%
genres=df["listed_in"].str.split(",").explode().str.strip()
most_common=genres.value_counts()

# %%
most_common.plot(kind="pie",autopct="%1.1f%%")
# Out:
# <Axes: ylabel='listed_in'>

# %%
movies=df[df["type"]=="movie"]
moviesss=pd.to_numeric(movies["duration"].str.replace("min",''),errors="coerce")
bins=[0,25,50,75,100,125,150,175,200]

# %%
moviesss.plot(kind="hist",x="moviesss",edgecolor="black",bins=bins)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # KEY INSIGHTS FROM OUR DATA ANALYSIS

# %% [markdown]
# ### 1. United States is the country which produces the most content(3684)
# ### 2. 1146 Movies and TV Shows were released in the year 2018
# ### 3. Most common genre is " INTERNATIONAL MOVIES(2752)"
# ### 4. Most of the content is released after 2015
# ### 5. TV shows is the least common genre(16)

# %%
df.to_csv("netflix_analysis.csv")
